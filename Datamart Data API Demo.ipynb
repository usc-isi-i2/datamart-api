# %% [markdown]
# # This is a tutorial/demo on how to use the `Datamart` REST API.

# %% [markdown]
# ## Installation
#
# This Jupyter notebook requires at least Python 3.3 with these packages installed:
#
# ```
# pip install notebook
# pip install requests
# pip install pandas
# ```
#
# To run change to the directory containing this notebook, and type
#
# ```
# jupyter notebook
# ```
#
# Then, open this page in the web browser: http://localhost:8888/notebooks/Datamart%20Data%20API%20Demo.ipynb

# %% [markdown]
# ## Configuration
#
# By default the this notebook accesses the Datamart REST API server at ISI. Edit the cell below to choose a different server.
#
# To run you own server **locally** follow the instructions here: [README](README.md)

# %%
## set datamart api url
# The datamart server running at ISI
# datamart_api_url = 'https://datamart:datamart-api-789@dsbox02.isi.edu:8888/datamart-api-wm'

# Datamart server running on localhost
# datamart_api_url = 'http://localhost:14080'

# Datamart server running on localhost in development mode
datamart_api_url = 'http://localhost:12543'

# %% [markdown]
# ## Import python modules

# %%
from requests import get,post,put,delete
import json
import pandas as pd
from io import StringIO
from IPython.display import display, HTML

# %% [markdown]
# ### Get all datasets

# %% [markdown]
# **GET `/metadata/datasets`**

# %%
response = get(f'{datamart_api_url}/metadata/datasets')
df = pd.DataFrame(response.json())
df
# Out:
#                                              name  \
# 0                                  UAZ Indicators
# 1                                     WDI dataset
# 2                    Corruption Perceptions Index
# 3                      SIPRI Military Expenditure
# 4                        economic fitness dataset
# 5   Agricultural Market Information System (AMIS)
# 6                                  test test test
# 7                       World Press Freedom Index
# 8                          Poverty Rate Global DP
# 9                                     FSI dataset
# 10                                   OECD dataset
# 11                                    WGI dataset
#
#                                           description  \
# 0   Collection of indicators, including indicators...
# 1                        World Development Indicators
# 2   Transparency International  Corruption Percept...
# 3   Military expenditure by country, in millions o...
# 4                                     EconomicFitness
# 5   The Agricultural Market Information System (AM...
# 6                                          testy test
# 7   Published every year since 2002 by Reporters W...
# 8                              Poverty Rate Global DP
# 9                            data downloaded from FSI
# 10                          data downloaded from OECD
# 11                    Worldwide Governance Indicators
#
#                                                   url       dataset_id
# 0                     https://github.com/ml4ai/delphi              UAZ
# 1   https://databank.worldbank.org/source/world-de...              WDI
# 2                       https://www.transparency.org/            TICPI
# 3                   https://sipri.org/databases/milex            SIPRI
# 4   https://databank.banquemondiale.org/source/eco...  EconomicFitness
# 5                         http://www.amis-outlook.org             AMIS
# 6                                    https://test.com          TEST000
# 7                                  https://rsf.org/en             WPFI
# 8                                          http://url        DPPoverty
# 9                      https://fragilestatesindex.org              FSI
# 10                              https://data.oecd.org             OECD
# 11  https://databank.worldbank.org/source/worldwid...              WGI

# %% [markdown]
# As of June 25, 2020 there are 11 datasets in the database. More datasets will be added as they are processed.
#
# We can also get metadata about one dataset using the `dataset_id`.

# %% [markdown]
# ### Get metadata about one dataset

# %% [markdown]
# **GET `/metadata/datasets/{dataset_id}`**

# %%
response = get(f'{datamart_api_url}/metadata/datasets/WDI')
df = pd.DataFrame(response.json())
df
# Out:
#           name                   description  \
# 0  WDI dataset  World Development Indicators
#
#                                                  url dataset_id
# 0  https://databank.worldbank.org/source/world-de...        WDI

# %% [markdown]
# ### Get all variables in a dataset

# %% [markdown]
# **GET `/metadata/datasets/{dataset_id}/variables`**

# %%
response = get(f'{datamart_api_url}/metadata/datasets/WDI/variables')
print(json.dumps(response.json()[:5], indent=2)) # print only 5 variables
# Out:
# [
#   {
#     "name": "_2005 PPP conversion factor, GDP (LCU per international $)",
#     "variable_id": "_2005_ppp_conversion_factor_gdp_lcu_per_international",
#     "description": "_2005 PPP conversion factor, GDP (LCU per international $) in WDI",
#     "corresponds_to_property": "PWDI-002",
#     "qualifier": [
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       }
#     ]
#   },
#   {
#     "name": "_2005 PPP conversion factor, private consumption (LCU per international $)",
#     "variable_id": "_2005_ppp_conversion_factor_private_consumption_lcu_per_international",
#     "description": "_2005 PPP conversion factor, private consumption (LCU per international $) in WDI",
#     "corresponds_to_property": "PWDI-003",
#     "qualifier": [
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       }
#     ]
#   },
#   {
#     "name": "Access to clean fuels and technologies for cooking (% of population)",
#     "variable_id": "access_to_clean_fuels_and_technologies_for_cooking_of_population",
#     "description": "Access to clean fuels and technologies for cooking (% of population) in WDI",
#     "corresponds_to_property": "PWDI-004",
#     "qualifier": [
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       }
#     ]
#   },
#   {
#     "name": "Access to electricity (% of population)",
#     "variable_id": "access_to_electricity_of_population",
#     "description": "Access to electricity (% of population) in WDI",
#     "corresponds_to_property": "PWDI-005",
#     "qualifier": [
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       }
#     ]
#   },
#   {
#     "name": "Access to electricity, rural (% of rural population)",
#     "variable_id": "access_to_electricity_rural_of_rural_population",
#     "description": "Access to electricity, rural (% of rural population) in WDI",
#     "corresponds_to_property": "PWDI-006",
#     "qualifier": [
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       }
#     ]
#   }
# ]

# %%
print('Total number of variables in dataset: {} is {}'.format('WDI', len(response.json())))
# Out:
# Total number of variables in dataset: WDI is 1429

# %% [markdown]
# ### Get metadata about one variable

# %% [markdown]
# **GET `/metadata/datasets/{dataset_id}/variables/{variable_id}`**

# %%
response = get(f'{datamart_api_url}/metadata/datasets/WDI/variables/access_to_electricity_of_population')
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "name": "Access to electricity (% of population)",
#   "variable_id": "access_to_electricity_of_population",
#   "dataset_id": "WDI",
#   "description": "Access to electricity (% of population) in WDI",
#   "corresponds_to_property": "PWDI-005",
#   "qualifier": [
#     {
#       "name": "point in time",
#       "identifier": "P585"
#     },
#     {
#       "name": "stated in",
#       "identifier": "P248"
#     }
#   ]
# }

# %% [markdown]
# ### Find a variable using keyword search

# %% [markdown]
# **GET `/metadata/variables?keyword={keyword}`**
#
# Query for datasets related to: **road**

# %%
response = get(f'{datamart_api_url}/metadata/variables?keyword=road')
df = pd.DataFrame(response.json())
df
# Out:
#                                          variable_id  \
# 0  mortality_caused_by_road_traffic_injury_per_10...
# 1                                    road_fatalities
# 2                                          VUAZ-8054
#
#                                                 name      rank dataset_id
# 0   Mortality caused by road traffic injury (per ...  0.075991        WDI
# 1                                    Road Fatalities  0.075991       OECD
# 2   WDI: Mortality caused by road traffic injury[...  0.060793        UAZ

# %% [markdown]
# Query datasets related to: **road AND fatalities**

# %%
response = get(f'{datamart_api_url}/metadata/variables?keyword=road fatalities')
df = pd.DataFrame(response.json())
df
# Out:
#        variable_id              name      rank dataset_id
# 0  road_fatalities   Road Fatalities  0.334428       OECD

# %% [markdown]
# Query datasets related to: **road OR fatalities**

# %%
response = get(f'{datamart_api_url}/metadata/variables?keyword=road&keyword=fatalities')
df = pd.DataFrame(response.json())
df
# Out:
#                                          variable_id  \
# 0                                    road_fatalities
# 1  mortality_caused_by_road_traffic_injury_per_10...
# 2                                          VUAZ-8054
# 3                                          VUAZ-8136
#
#                                                 name      rank dataset_id
# 0                                    Road Fatalities  0.075991       OECD
# 1   Mortality caused by road traffic injury (per ...  0.037995        WDI
# 2   WDI: Mortality caused by road traffic injury[...  0.030396        UAZ
# 3               Conflict fatalities[number of cases]  0.030396        UAZ

# %% [markdown]
# ### Find a variable for a given location

# %% [markdown]
# **GET `/metadata/variables?country={keyword}`**
#
# Find variables containing data in a given **country**

# %%
response = get(f'{datamart_api_url}/metadata/variables?country=Ethiopia')
df = pd.DataFrame(response.json())
df.head(20)
# Out:
#        variable_id                                      variable_text  \
# 0          rd_dsty  'census':6 'column':2 'dsti':9 'partial':7 'qe...
# 1     avg_tra_time  'avg':8 'census':6 'column':2 'partial':7 'qet...
# 2       mean_slope  'census':6 'column':2 'mean':8 'partial':7 'qe...
# 3   mean_elevation  'census':6 'column':2 'elev':9 'mean':8 'parti...
# 4           VUAZ-1  'bioenergi':2,11 'energi':9 'fao':1 'product':...
# 5           VUAZ-9  'agricultur':9 'ch4':3 'emiss':2 'energi':4 'e...
# 6           VUAZ-0  'agricultur':2,16 'energi':5,11,13 'fao':1 'fo...
# 7           VUAZ-2  'agricultur':4 'consumpt':2 'energi':5 'fao':1...
# 8           VUAZ-3  'agricultur':4 'consumpt':2 'fao':1 'fisheri':...
# 9           VUAZ-4  'agricultur':4 'consumpt':2 'diesel':7 'fao':1...
# 10          VUAZ-5  'agricultur':4,9 'consumpt':2 'excl':10 'fao':...
# 11          VUAZ-6  'ch4':3 'emiss':2 'energi':4,5 'fao':1 'fisher...
# 12          VUAZ-7  'ch4':3 'emiss':2 'energi':4 'fao':1 'fisheri'...
# 13          VUAZ-8  'ch4':3 'diesel':7 'emiss':2 'energi':4 'fao':...
# 14         VUAZ-10  'co2':3 'emiss':2 'energi':4,5 'fao':1 'fisher...
# 15         VUAZ-11  'co2':3 'emiss':2 'energi':4 'fao':1 'fisheri'...
# 16         VUAZ-12  'co2':3 'diesel':7 'emiss':2 'energi':4 'fao':...
# 17         VUAZ-13  'agricultur':9 'co2':3 'emiss':2 'energi':4 'e...
# 18         VUAZ-14  'co2eq':3 'emiss':2 'energi':4,5 'fao':1 'fish...
# 19         VUAZ-15  'co2eq':3 'emiss':2 'energi':4 'fao':1 'fisher...
#
#                                                  name          dataset_id
# 0                                             RD_DSTY  Eth-census-partial
# 1                                        AVG_TRA_TIME  Eth-census-partial
# 2                                          MEAN_SLOPE  Eth-census-partial
# 3                                      MEAN_ELEVATION  Eth-census-partial
# 4    FAO: Bioenergy production as a % of total ren...                 UAZ
# 5    FAO: Emissions (CH4) (Energy), Transport fuel...                 UAZ
# 6    FAO: Agriculture and forestry energy use as a...                 UAZ
# 7    FAO: Consumption in Agriculture, Energy used ...                 UAZ
# 8    FAO: Consumption in Agriculture, Fuel oil use...                 UAZ
# 9    FAO: Consumption in Agriculture, Gas-diesel o...                 UAZ
# 10   FAO: Consumption in Agriculture, Transport fu...                 UAZ
# 11   FAO: Emissions (CH4) (Energy), Energy used in...                 UAZ
# 12   FAO: Emissions (CH4) (Energy), Fuel oil used ...                 UAZ
# 13   FAO: Emissions (CH4) (Energy), Gas-diesel oil...                 UAZ
# 14   FAO: Emissions (CO2) (Energy), Energy used in...                 UAZ
# 15   FAO: Emissions (CO2) (Energy), Fuel oil used ...                 UAZ
# 16   FAO: Emissions (CO2) (Energy), Gas-diesel oil...                 UAZ
# 17   FAO: Emissions (CO2) (Energy), Transport fuel...                 UAZ
# 18   FAO: Emissions (CO2eq) (Energy), Energy used ...                 UAZ
# 19   FAO: Emissions (CO2eq) (Energy), Fuel oil use...                 UAZ

# %% [markdown]
# **GET `/metadata/variables?admin={keyword}`**
#
# Find variables containing data in a given **admin region**

# %%
response = get(f'{datamart_api_url}/metadata/variables?admin=oromia')
df = pd.DataFrame(response.json())
df.head(20)
# Out:
#        variable_id                                      variable_text  \
# 0          rd_dsty  'census':6 'column':2 'dsti':9 'partial':7 'qe...
# 1     avg_tra_time  'avg':8 'census':6 'column':2 'partial':7 'qet...
# 2       mean_slope  'census':6 'column':2 'mean':8 'partial':7 'qe...
# 3   mean_elevation  'census':6 'column':2 'elev':9 'mean':8 'parti...
# 4           VUAZ-1  'bioenergi':2,11 'energi':9 'fao':1 'product':...
# 5           VUAZ-9  'agricultur':9 'ch4':3 'emiss':2 'energi':4 'e...
# 6           VUAZ-0  'agricultur':2,16 'energi':5,11,13 'fao':1 'fo...
# 7           VUAZ-2  'agricultur':4 'consumpt':2 'energi':5 'fao':1...
# 8           VUAZ-3  'agricultur':4 'consumpt':2 'fao':1 'fisheri':...
# 9           VUAZ-4  'agricultur':4 'consumpt':2 'diesel':7 'fao':1...
# 10          VUAZ-5  'agricultur':4,9 'consumpt':2 'excl':10 'fao':...
# 11          VUAZ-6  'ch4':3 'emiss':2 'energi':4,5 'fao':1 'fisher...
# 12          VUAZ-7  'ch4':3 'emiss':2 'energi':4 'fao':1 'fisheri'...
# 13          VUAZ-8  'ch4':3 'diesel':7 'emiss':2 'energi':4 'fao':...
# 14         VUAZ-10  'co2':3 'emiss':2 'energi':4,5 'fao':1 'fisher...
# 15         VUAZ-11  'co2':3 'emiss':2 'energi':4 'fao':1 'fisheri'...
# 16         VUAZ-12  'co2':3 'diesel':7 'emiss':2 'energi':4 'fao':...
# 17         VUAZ-13  'agricultur':9 'co2':3 'emiss':2 'energi':4 'e...
# 18         VUAZ-14  'co2eq':3 'emiss':2 'energi':4,5 'fao':1 'fish...
# 19         VUAZ-15  'co2eq':3 'emiss':2 'energi':4 'fao':1 'fisher...
#
#                                                  name          dataset_id
# 0                                             RD_DSTY  Eth-census-partial
# 1                                        AVG_TRA_TIME  Eth-census-partial
# 2                                          MEAN_SLOPE  Eth-census-partial
# 3                                      MEAN_ELEVATION  Eth-census-partial
# 4    FAO: Bioenergy production as a % of total ren...                 UAZ
# 5    FAO: Emissions (CH4) (Energy), Transport fuel...                 UAZ
# 6    FAO: Agriculture and forestry energy use as a...                 UAZ
# 7    FAO: Consumption in Agriculture, Energy used ...                 UAZ
# 8    FAO: Consumption in Agriculture, Fuel oil use...                 UAZ
# 9    FAO: Consumption in Agriculture, Gas-diesel o...                 UAZ
# 10   FAO: Consumption in Agriculture, Transport fu...                 UAZ
# 11   FAO: Emissions (CH4) (Energy), Energy used in...                 UAZ
# 12   FAO: Emissions (CH4) (Energy), Fuel oil used ...                 UAZ
# 13   FAO: Emissions (CH4) (Energy), Gas-diesel oil...                 UAZ
# 14   FAO: Emissions (CO2) (Energy), Energy used in...                 UAZ
# 15   FAO: Emissions (CO2) (Energy), Fuel oil used ...                 UAZ
# 16   FAO: Emissions (CO2) (Energy), Gas-diesel oil...                 UAZ
# 17   FAO: Emissions (CO2) (Energy), Transport fuel...                 UAZ
# 18   FAO: Emissions (CO2eq) (Energy), Energy used ...                 UAZ
# 19   FAO: Emissions (CO2eq) (Energy), Fuel oil use...                 UAZ

# %% [markdown]
# ### Get time series data for a variable

# %% [markdown]
# **GET `/datasets/{dataset_id}/variables/{variable_id}`**

# %%
response = get(f'{datamart_api_url}/datasets/WDI/variables/access_to_electricity_of_population')
df = pd.read_csv(StringIO(response.text))
display(HTML(df.fillna('').head(20).to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>73.600000</td>
#       <td></td>
#       <td>2000-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>76.344460</td>
#       <td></td>
#       <td>2001-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>77.307663</td>
#       <td></td>
#       <td>2002-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>78.251656</td>
#       <td></td>
#       <td>2003-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>79.171516</td>
#       <td></td>
#       <td>2004-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>81.600000</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>80.943794</td>
#       <td></td>
#       <td>2006-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>81.820259</td>
#       <td></td>
#       <td>2007-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>82.708366</td>
#       <td></td>
#       <td>2008-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>83.621689</td>
#       <td></td>
#       <td>2009-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>92.389572</td>
#       <td></td>
#       <td>2010-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>90.631691</td>
#       <td></td>
#       <td>2011-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>89.300000</td>
#       <td></td>
#       <td>2012-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>86.400000</td>
#       <td></td>
#       <td>2013-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>88.803612</td>
#       <td></td>
#       <td>2014-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>89.926506</td>
#       <td></td>
#       <td>2015-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>91.058128</td>
#       <td></td>
#       <td>2016-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Ga

# %% [markdown]
# ### Get time series data for a variable for a country

# %% [markdown]
# **GET `/datasets/{dataset_id}/variables/{variable_id}?country={country}`**
#
# Get data for **Gabon**

# %%
response = get(f'{datamart_api_url}/datasets/WDI/variables/access_to_electricity_of_population?country=Gabon')
df = pd.read_csv(StringIO(response.text))
display(HTML(df.fillna('').to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>73.600000</td>
#       <td></td>
#       <td>2000-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>76.344460</td>
#       <td></td>
#       <td>2001-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>77.307663</td>
#       <td></td>
#       <td>2002-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>78.251656</td>
#       <td></td>
#       <td>2003-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>79.171516</td>
#       <td></td>
#       <td>2004-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>81.600000</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>80.943794</td>
#       <td></td>
#       <td>2006-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>81.820259</td>
#       <td></td>
#       <td>2007-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>82.708366</td>
#       <td></td>
#       <td>2008-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>83.621689</td>
#       <td></td>
#       <td>2009-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>92.389572</td>
#       <td></td>
#       <td>2010-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>90.631691</td>
#       <td></td>
#       <td>2011-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>89.300000</td>
#       <td></td>
#       <td>2012-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>86.400000</td>
#       <td></td>
#       <td>2013-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>88.803612</td>
#       <td></td>
#       <td>2014-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>89.926506</td>
#       <td></td>
#       <td>2015-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>91.058128</td>
#       <td></td>
#       <td>2016-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Ga

# %% [markdown]
# Get data for **Gabon OR Guinea**

# %%
response = get(f'{datamart_api_url}/datasets/WDI/variables/access_to_electricity_of_population?country=Gabon&country=Guinea')
df = pd.read_csv(StringIO(response.text))
display(HTML(df.fillna('').to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>73.600000</td>
#       <td></td>
#       <td>2000-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>76.344460</td>
#       <td></td>
#       <td>2001-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>77.307663</td>
#       <td></td>
#       <td>2002-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>78.251656</td>
#       <td></td>
#       <td>2003-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>79.171516</td>
#       <td></td>
#       <td>2004-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>81.600000</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>80.943794</td>
#       <td></td>
#       <td>2006-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>81.820259</td>
#       <td></td>
#       <td>2007-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>82.708366</td>
#       <td></td>
#       <td>2008-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>83.621689</td>
#       <td></td>
#       <td>2009-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>92.389572</td>
#       <td></td>
#       <td>2010-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>90.631691</td>
#       <td></td>
#       <td>2011-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>89.300000</td>
#       <td></td>
#       <td>2012-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>86.400000</td>
#       <td></td>
#       <td>2013-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>88.803612</td>
#       <td></td>
#       <td>2014-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>89.926506</td>
#       <td></td>
#       <td>2015-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_electricity_of_population</td>
#       <td>Access to electricity (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>91.058128</td>
#       <td></td>
#       <td>2016-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Ga

# %% [markdown]
# ### Get time series data for all variables in a dataset

# %% [markdown]
# **GET `/datasets/{dataset_id}/variables`**

# %% [markdown]
# **Please note that this API will return data for 20 variables only, by default. However that limit can be increased by setting the limit in the url**
#
# For example, to fetch 50 variables,
#
# **GET `/datasets/{dataset_id}/variables?limit=50`**

# %%
response = get(f'{datamart_api_url}/datasets/WDI/variables')
df = pd.read_csv(StringIO(response.text), dtype=object)
print(f'Number of rows in the file: {len(df)}')
display(HTML(df.fillna('').head(20).to_html(index=False)))
# Out:
# Number of rows in the file: 29311
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>256.2303101</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>The Gambia</td>
#       <td>Q1005</td>
#       <td>7.560359062</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>The Gambia</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-15.5 13.5)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Guinea</td>
#       <td>Q1006</td>
#       <td>1219.348401</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Guinea</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-11.0 10.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Guinea-Bissau</td>
#       <td>Q1007</td>
#       <td>217.3003471</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Guinea-Bissau</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-15.0 12.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Cameroon</td>
#       <td>Q1009</td>
#       <td>251.0153029</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Cameroon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(12.0 7.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Cape Verde</td>
#       <td>Q1011</td>
#       <td>69.3602975</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Cape Verde</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-24.083333333333 15.916666666667)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Lesotho</td>
#       <td>Q1013</td>
#       <td>3.490095754</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Lesotho</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(28.25 -29.55)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Liberia</td>
#       <td>Q1014</td>
#       <td>0.492553151</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Liberia</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-9.75 6.533333)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Libya</td>
#       <td>Q1016</td>
#       <td>0.7345614</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Libya</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(17.0 27.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Madagascar</td>
#       <td>Q1019</td>
#       <td>649.5681317</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Madagascar</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(47.0 -20.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Malawi</td>
#       <td>Q1020</td>
#       <td>39.45659876</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Malawi</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(34.0 -13.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Mauritania</td>
#       <td>Q1025</td>
#       <td>98.83950107</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Mauritania</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-11.0 21.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Mauritius</td>
#       <td>Q1027</td>
#       <td>14.67715916</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Mauritius</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(57.5 -20.2)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Morocco</td>
#       <td>Q1028</td>
#       <td>4.878183642</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Morocco</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(-6.0 32.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Mozambique</td>
#       <td>Q1029</td>
#       <td>10.90944986</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Mozambique</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(35.0 -19.0)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>_2005_ppp_conversion_factor_gdp_lcu_per_international</td>
#       <td>_2005 PPP conversion factor, GDP (LCU per international $)</td>
#       <td>Namibia</td>

# %% [markdown]
# ### Get time series for multiple variables in a dataset

# %% [markdown]
# **GET `/datasets/{dataset_id}/variables?variable={variable_id}`**
#
# Get data for variables **`access_to_clean_fuels_and_technologies_for_cooking_of_population` AND
# `access_to_electricity_of_population`**

# %%
response = get(f'{datamart_api_url}/datasets/WDI/variables?variable=access_to_clean_fuels_and_technologies_for_cooking_of_population&variable=access_to_electricity_of_population')
df = pd.read_csv(StringIO(response.text))
# display only 30 rows
display(HTML(df.fillna('').head(30).to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>58.72</td>
#       <td></td>
#       <td>2000-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>60.59</td>
#       <td></td>
#       <td>2001-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>62.40</td>
#       <td></td>
#       <td>2002-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>64.33</td>
#       <td></td>
#       <td>2003-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>65.35</td>
#       <td></td>
#       <td>2004-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>67.19</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>68.85</td>
#       <td></td>
#       <td>2006-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>69.84</td>
#       <td></td>
#       <td>2007-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>71.14</td>
#       <td></td>
#       <td>2008-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>72.06</td>
#       <td></td>
#       <td>2009-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>73.57</td>
#       <td></td>
#       <td>2010-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>74.64</td>
#       <td></td>
#       <td>2011-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>75.75</td>
#       <td></td>
#       <td>2012-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>76.53</td>
#       <td></td>
#       <td>2013-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>77.30</td>
#       <td></td>
#       <td>2014-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333

# %% [markdown]
# ### Get time series for multiple variables in a dataset, filter by country

# %% [markdown]
# **GET `/datasets/{dataset_id}/variables?variable={variable_id}&country={country}`**
#
# Get data for variables
# **`access_to_clean_fuels_and_technologies_for_cooking_of_population` AND
# `access_to_electricity_of_population`**
# and country **Gabon**

# %%
response = get(f'{datamart_api_url}/datasets/WDI/variables?variable=access_to_clean_fuels_and_technologies_for_cooking_of_population&variable=access_to_electricity_of_population&country=Gabon')
df = pd.read_csv(StringIO(response.text))
display(HTML(df.fillna('').to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>58.720000</td>
#       <td></td>
#       <td>2000-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>60.590000</td>
#       <td></td>
#       <td>2001-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>62.400000</td>
#       <td></td>
#       <td>2002-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>64.330000</td>
#       <td></td>
#       <td>2003-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>65.350000</td>
#       <td></td>
#       <td>2004-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>67.190000</td>
#       <td></td>
#       <td>2005-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>68.850000</td>
#       <td></td>
#       <td>2006-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>69.840000</td>
#       <td></td>
#       <td>2007-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>71.140000</td>
#       <td></td>
#       <td>2008-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>72.060000</td>
#       <td></td>
#       <td>2009-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>73.570000</td>
#       <td></td>
#       <td>2010-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>74.640000</td>
#       <td></td>
#       <td>2011-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>75.750000</td>
#       <td></td>
#       <td>2012-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>76.530000</td>
#       <td></td>
#       <td>2013-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(11.5 -0.68333055555556)</td>
#       <td></td>
#       <td></td>
#       <td>WDI</td>
#     </tr>
#     <tr>
#       <td>WDI</td>
#       <td>access_to_clean_fuels_and_technologies_for_cooking_of_population</td>
#       <td>Access to clean fuels and technologies for cooking (% of population)</td>
#       <td>Gabon</td>
#       <td>Q1000</td>
#       <td>77.300000</td>
#       <td></td>
#       <td>2014-01-01T00:00:00Z</td>
#       <td>year</td>
#       <td>Gabon</td>
#       <td></td>

# %% [markdown]
# ### Create a new dataset
#
# **NOTE: If the following POST methods have already been ran against the Datamart server, then server will respond with error messages.**

# %% [markdown]
# **POST `/metadata/datasets`**

# %%
# Define a new dataset
test_dataset = {
    "name": "TEST01",
    "dataset_id": "TEST01",
    "description": "TEST01",
    "url": "http://test01.com/test"
}

# %%
# post it to the API
td_response = post(f'{datamart_api_url}/metadata/datasets', json=test_dataset)
print(json.dumps(td_response.json(), indent=2))
# Out:
# {
#   "name": "TEST01",
#   "description": "TEST01",
#   "url": "http://test01.com/test",
#   "dataset_id": "TEST01"
# }

# %% [markdown]
# **NOTE: If the above POST method has already been ran against this Datamart server, then server will respond with:**
#
# ```
# {
#   "Error": "Dataset identifier TEST01 has already been used"
# }
# ```

# %% [markdown]
# Retrieve all datasets

# %%
response = get(f'{datamart_api_url}/metadata/datasets')
df = pd.DataFrame(response.json())
df
# Out:
#                                              name  \
# 0                                  UAZ Indicators
# 1                                     WDI dataset
# 2                    Corruption Perceptions Index
# 3                      SIPRI Military Expenditure
# 4                        economic fitness dataset
# 5   Agricultural Market Information System (AMIS)
# 6                                  test test test
# 7                       World Press Freedom Index
# 8                          Poverty Rate Global DP
# 9                                     FSI dataset
# 10                                   OECD dataset
# 11                                    WGI dataset
# 12                                            GDL
# 13                                   aid-security
# 14                                           awsd
# 15                                      test_time
# 16                                  t2wml_test_04
# 17                          unittestuploaddataset
# 18                                      hces_test
# 19                                  t2wml_test_05
# 20            Aid Worker Security Database (AWSD)
# 21                                        test_02
# 22                                  t2wml_test_07
# 23                                  t2wml_test_08
# 24                                  t2wml_test_02
# 25                                     Eth-census
# 26                             Eth-census-partial
# 27                                         TEST04
# 28                                         TEST01
#
#                                           description  \
# 0   Collection of indicators, including indicators...
# 1                        World Development Indicators
# 2   Transparency International  Corruption Percept...
# 3   Military expenditure by country, in millions o...
# 4                                     EconomicFitness
# 5   The Agricultural Market Information System (AM...
# 6                                          testy test
# 7   Published every year since 2002 by Reporters W...
# 8                              Poverty Rate Global DP
# 9                            data downloaded from FSI
# 10                          data downloaded from OECD
# 11                    Worldwide Governance Indicators
# 12                                         Aid worker
# 13                                         Aid worker
# 14                                         Aid worker
# 15                                 Describe test_time
# 16                             Describe t2wml_test_04
# 17                     Describe unittestuploaddataset
# 18                                 Describe hces_test
# 19                             Describe t2wml_test_05
# 20  he Aid Worker Security Database (AWSD) records...
# 21                               Test dataset test_02
# 22                         Test dataset t2wml_test_07
# 23                         Test dataset t2wml_test_08
# 24                         Test dataset t2wml_test_02
# 25                            Test dataset Eth-census
# 26                    Test dataset Eth-census-partial
# 27                                             TEST04
# 28                                             TEST01
#
#                                                   url             dataset_id
# 0                     https://github.com/ml4ai/delphi                    UAZ
# 1   https://databank.worldbank.org/source/world-de...                    WDI
# 2                       https://www.transparency.org/                  TICPI
# 3                   https://sipri.org/databases/milex                  SIPRI
# 4   https://databank.banquemondiale.org/source/eco...        EconomicFitness
# 5                         http://www.amis-outlook.org                   AMIS
# 6                                    https://test.com                TEST000
# 7                                  https://rsf.org/en                   WPFI
# 8                                          http://url              DPPoverty
# 9                      https://fragilestatesindex.org                    FSI
# 10                              https://data.oecd.org                   OECD
# 11  https://databank.worldbank.org/source/worldwid...                    WGI
# 12                                        http://awsd                    GDL
# 13                                        http://awsd           aid-security
# 14                                        http://awsd                   awsd
# 15                             https://test_time.org/              test_time
# 16                         https://t2wml_test_04.org/          t2wml_test_04
# 17                 https://unittestuploaddataset.org/  unittestuploaddataset
# 18                             https://hces_test.org/              hces_test
# 19                         https://t2wml_test_05.org/          t2wml_test_05
# 20                     https://aidworkersecurity.org/        aid_worker_test
# 21                               https://test_02.org/                test_02
# 22                         https://t2wml_test_07.org/          t2wml_test_07
# 23                         https://t2wml_test_08.org/          t2wml_test_08
# 24                         https://t2wml_test_02.org/          t2wml_test_02
# 25                            https://Eth-census.org/             Eth-census
# 26                    https://Eth-census-partial.org/     Eth-census-partial
# 27                             http://test01.com/test                 TEST04
# 28                             http://test01.com/test                 TEST01

# %% [markdown]
# The newly created dataset `TEST01` is returned

# %% [markdown]
# ### Create a variable in the dataset `TEST01`

# %% [markdown]
# **POST `/metadata/datasets/{dataset_id}/variables`**

# %%
# define a new variable
test_variable = {
    "name": "test variable for test dataset",
    "variable_id": "TEST01-01"
}

# %%
tv_response = post(f'{datamart_api_url}/metadata/datasets/TEST01/variables', json=test_variable)
print(json.dumps(tv_response.json(), indent=2))
# Out:
# {
#   "name": "test variable for test dataset",
#   "variable_id": "TEST01-01",
#   "dataset_id": "TEST01",
#   "corresponds_to_property": "PTEST01-TEST01-01"
# }

# %% [markdown]
# **NOTE: If the above POST method has already been ran against this Datamart server, then server will respond with:**
#
# ```
# {
#   "Error": "Variable TEST01-01 has already been defined in dataset TEST01"
# }
# ```

# %% [markdown]
# Retrieve all variables for the dataset `TEST01`

# %%
response = get(f'{datamart_api_url}/metadata/datasets/TEST01/variables')
df = pd.DataFrame(response.json())
df
# Out:
#                              name variable_id                     description  \
# 0  test variable for test dataset   TEST01-01  test variable for test dataset
#
#   corresponds_to_property
# 0       PTEST01-TEST01-01

# %% [markdown]
# The variable `TEST01-01` is created in the dataset `TEST01`

# %% [markdown]
# ### Upload data to a variable

# %% [markdown]
# **The upload API is now deprecated, because we now support upload Annotated Spreadsheet API #Upload-an-Annotated-spreadsheet**

# %% [markdown]
# ### Upload an Annotated spreadsheet

# %% [markdown]
# We can upload an annotated spreadsheet for a dataset as well. Annotation example - https://docs.google.com/spreadsheets/d/1fLEPvEu9OuKa2_7BEzhY0oWGZ_9CMXEE/edit#gid=280610980

# %% [markdown]
# **POST `datasets/{dataset_id}/annotated`**

# %% [markdown]
# Lets upload a sample annotated file to the dataset `TEST01`

# %%
import os
def upload_data_post(file_path, url):
    file_name = os.path.basename(file_path)
    files = {
        'file': (file_name, open(file_path, mode='rb'), 'application/octet-stream')
    }
    response = post(url, files=files)
    if response.status_code == 400:
        print(json.dumps(response.json(), indent=2))
    else:
        print(json.dumps(response.json(), indent=2))

# %%
test_dataset = {
    "name": "TESTAID",
    "dataset_id": "TESTAID",
    "description": "TESTAID",
    "url": "http://testaid.com/test"
}
td_response = post(f'{datamart_api_url}/metadata/datasets', json=test_dataset)
print(json.dumps(td_response.json(), indent=2))
# Out:
# {
#   "name": "TESTAID",
#   "description": "TESTAID",
#   "url": "http://testaid.com/test",
#   "dataset_id": "TESTAID"
# }

# %%
url = f'{datamart_api_url}/datasets/TESTAID/annotated'
file_path = 'test/test_data/demo_annotated_aid_worker.xlsx'
upload_data_post(file_path, url)
# Out:
# [
#   {
#     "name": "INGO",
#     "variable_id": "ingo",
#     "dataset_id": "TESTAID",
#     "description": "variable column in QTESTAID",
#     "corresponds_to_property": "PVARIABLE-QTESTAID-003",
#     "qualifier": [
#       {
#         "name": "Location",
#         "identifier": "PQUALIFIER-QTESTAID-006",
#         "data_type": "String"
#       },
#       {
#         "name": "Attack context",
#         "identifier": "PQUALIFIER-QTESTAID-005",
#         "data_type": "String"
#       },
#       {
#         "name": "Means of attack",
#         "identifier": "PQUALIFIER-QTESTAID-004",
#         "data_type": "String"
#       },
#       {
#         "name": "City",
#         "identifier": "PQUALIFIER-QTESTAID-002",
#         "data_type": "String"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       },
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       }
#     ]
#   }
# ]

# %%
response = get(f'{datamart_api_url}/metadata/datasets/TESTAID/variables')
print(len(response.json()))
print(json.dumps(response.json(), indent=2)) # print only 5 variables
# Out:
# 1
# [
#   {
#     "name": "INGO",
#     "variable_id": "ingo",
#     "description": "variable column in QTESTAID",
#     "corresponds_to_property": "PVARIABLE-QTESTAID-003",
#     "qualifier": [
#       {
#         "name": "Location",
#         "identifier": "PQUALIFIER-QTESTAID-006",
#         "data_type": "String"
#       },
#       {
#         "name": "Attack context",
#         "identifier": "PQUALIFIER-QTESTAID-005",
#         "data_type": "String"
#       },
#       {
#         "name": "Means of attack",
#         "identifier": "PQUALIFIER-QTESTAID-004",
#         "data_type": "String"
#       },
#       {
#         "name": "City",
#         "identifier": "PQUALIFIER-QTESTAID-002",
#         "data_type": "String"
#       },
#       {
#         "name": "stated in",
#         "identifier": "P248"
#       },
#       {
#         "name": "point in time",
#         "identifier": "P585"
#       }
#     ]
#   }
# ]

# %%
response = get(f'{datamart_api_url}/datasets/TESTAID/variables/ingo')
df = pd.read_csv(StringIO(response.text))
display(HTML(df.fillna('').to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset_id</th>
#       <th>variable_id</th>
#       <th>variable</th>
#       <th>main_subject</th>
#       <th>main_subject_id</th>
#       <th>value</th>
#       <th>value_unit</th>
#       <th>time</th>
#       <th>time_precision</th>
#       <th>country</th>
#       <th>admin1</th>
#       <th>admin2</th>
#       <th>admin3</th>
#       <th>region_coordinate</th>
#       <th>stated_in</th>
#       <th>stated_in_id</th>
#       <th>Location</th>
#       <th>Attack context</th>
#       <th>Means of attack</th>
#       <th>City</th>
#       <th>stated in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>TESTAID</td>
#       <td>ingo</td>
#       <td>INGO</td>
#       <td>Ethiopia</td>
#       <td>Q115</td>
#       <td>0.0</td>
#       <td></td>
#       <td>1997-09-24T00:00:00Z</td>
#       <td>day</td>
#       <td>Ethiopia</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(40.0 9.0)</td>
#       <td></td>
#       <td></td>
#       <td>Unknown</td>
#       <td>Individual attack</td>
#       <td>Shooting</td>
#       <td>roadside</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>TESTAID</td>
#       <td>ingo</td>
#       <td>INGO</td>
#       <td>Ethiopia</td>
#       <td>Q115</td>
#       <td>0.0</td>
#       <td></td>
#       <td>1998-06-25T00:00:00Z</td>
#       <td>day</td>
#       <td>Ethiopia</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(40.0 9.0)</td>
#       <td></td>
#       <td></td>
#       <td>Road</td>
#       <td>Ambush</td>
#       <td>Kidnapping</td>
#       <td>travelling from Gode to Degeh Bur</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>TESTAID</td>
#       <td>ingo</td>
#       <td>INGO</td>
#       <td>Ethiopia</td>
#       <td>Q115</td>
#       <td>1.0</td>
#       <td></td>
#       <td>1999-04-01T00:00:00Z</td>
#       <td>day</td>
#       <td>Ethiopia</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>POINT(40.0 9.0)</td>
#       <td></td>
#       <td></td>
#       <td>Unknown</td>
#       <td>Unknown</td>
#       <td>Kidnapping</td>
#       <td>around the corner</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
