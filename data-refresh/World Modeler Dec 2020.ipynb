# %% [markdown]
# # Data Loader for World Modeler Dec 2020 Datasets

# %%
from pathlib import Path
import papermill as pm

WM_DATAMART_URL = 'https://datamart:datamart-api-789@dsbox02.isi.edu:8888/datamart-api-wm'
WM_TEST_URL = 'https://datamart:datamart-api-789dsbox02.isi.edu:8888/datamart-api-d3m'
LOCAL_URL = 'http://localhost:12543'

# %%
# Datamart URL
datamart_api_url = LOCAL_URL

# World Modeler shared data directory
shared_data_dir = Path('/lfs1/ktyao/Shared/kgtk-private-data/world-modelers')

# Directory where the git repositories are cloned. 
datamart_repos_dir = Path('/home/ktyao/dev/dsbox')

# %%
# datamart-api repository
datamart_dir = datamart_repos_dir / 'datamart-api'
data_refresh_dir = datamart_dir / 'data-refresh'

# Directory to store KGTK edge files
kgtk_dir = shared_data_dir / 'kgtk'

executed_notebook_dir = shared_data_dir / 'executed_notebook'

mitre_dir = shared_data_dir / 'MITRE Annotated Datasets for Dec 2020'

# %% [markdown]
# # Upload datasets

# %% [markdown]
# ## ACLED dataset

# %%
pm.execute_notebook(
    data_refresh_dir / 'DataLoader.ipynb',
    executed_notebook_dir / 'acled.ipynb',
    parameters=dict(
        datamart_api_url=datamart_api_url,
        annotated_path = str(mitre_dir / 'ACLED' / 'ACLED_1997-01-01-2020-11-12-Ethiopia_ANNOTATED_MODIFIED-partial.xlsx'),
        save_tsv_path = str(kgtk_dir / 'ACLED.tar.gz')))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=21.0, style=ProgressStyle(description_wid…
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:10.871672',
#      'end_time': '2020-11-25T05:20:10.890244',
#      'duration': 0.018572,
#      'status': 'completed'}},
#    'source': '# This is a demo on how to use the DataLoader to upload kgtk(\\*.tsv) and annotated spreadsheets (\\*.csv or \\*.xlsx) to Datamart'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:10.909923',
#      'end_time': '2020-11-25T05:20:10.926424',
#      'duration': 0.016501,
#      'status': 'completed'}},
#    'source': '## Current Support\n---\n`DataLoader` currently supports the following functionalities:\n1. `template` ++ `[spreadsheet]+` => `annotated_spreadsheet` => `Datamart` => `None`\n2. `annotated_spreadsheet` ++ `[yaml_file]?` => `Datamart` => **UNION**[`t2wml_output`, `exploded_kgtk`, `None`]\n3. `exploded_kgtk` => `Datamart` => `None`'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:10.942546',
#      'end_time': '2020-11-25T05:20:10.958542',
#      'duration': 0.015996,
#      'status': 'completed'}},
#    'source': '## Parameters\n\nUsers will be able to inject their parameters through commandline. Currently the following parameters are supported:'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:10.975753',
#      'end_time': '2020-11-25T05:20:11.007563',
#      'duration': 0.03181,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:11.002889Z',
#      'iopub.execute_input': '2020-11-25T05:20:11.003985Z',
#      'shell.execute_reply': '2020-11-25T05:20:11.006450Z',
#      'iopub.status.idle': '2020-11-25T05:20:11.007271Z'}},
#    'outputs': [],
#    'source': "# Parameters to be injected\n\ndatamart_api_url = 'http://localhost:12543'\n# [optional]\ndataset_id = None\nput_data = False\nDEBUG = False\n\n\n# [params] combining template and data\ntemplate_path = None\ndataset_path = None\n# [optional params]\nflag_combine_files = False\nsave_template_path = None\nsave_tsv_path = None\nsave_t2wml_path = None\nVerbose = False\n\n\n# [params] submitting one annotated spreadsheet\nannotated_path = None\n# [optional params]\nyamlfile_path = None    \n\n# [params] submitting kgtk file\ntsv_path = None\n\n\n# [params] erase one dataset\ndataset_id_to_erase = None"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.025723',
#      'end_time': '2020-11-25T05:20:11.050549',
#      'duration': 0.024826,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:11.046406Z',
#      'iopub.execute_input': '2020-11-25T05:20:11.047137Z',
#      'shell.execute_reply': '2020-11-25T05:20:11.049554Z',
#      'iopub.status.idle': '2020-11-25T05:20:11.050347Z'}},
#    'execution_count': 2,
#    'source': '# Parameters\ndatamart_api_url = "http://localhost:12543"\nannotated_path = "/lfs1/ktyao/Shared/kgtk-private-data/world-modelers/MITRE Annotated Datasets for Dec 2020/ACLED/ACLED_1997-01-01-2020-11-12-Ethiopia_ANNOTATED_MODIFIED-partial.xlsx"\nsave_tsv_path = "/lfs1/ktyao/Shared/kgtk-private-data/world-modelers/kgtk/ACLED.tar.gz"\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.067637',
#      'end_time': '2020-11-25T05:20:11.086786',
#      'duration': 0.019149,
#      'status': 'completed'}},
#    'source': '### Import python modules and utilities'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.103438',
#      'end_time': '2020-11-25T05:20:11.764576',
#      'duration': 0.661138,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:11.125854Z',
#      'iopub.execute_input': '2020-11-25T05:20:11.126572Z',
#      'shell.execute_reply': '2020-11-25T05:20:11.762962Z',
#      'iopub.status.idle': '2020-11-25T05:20:11.764210Z'}},
#    'outputs': [],
#    'source': 'from utils import spreadsheet, utility, upload, erase, template, test\n%matplotlib inline'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.788355',
#      'end_time': '2020-11-25T05:20:11.804927',
#      'duration': 0.016572,
#      'status': 'completed'}},
#    'source': '### Delete a dataset if needed'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.821563',
#      'end_time': '2020-11-25T05:20:11.848715',
#      'duration': 0.027152,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:11.844215Z',
#      'iopub.execute_input': '2020-11-25T05:20:11.844940Z',
#      'shell.execute_reply': '2020-11-25T05:20:11.847666Z',
#      'iopub.status.idle': '2020-11-25T05:20:11.848457Z'}},
#    'outputs': [],
#    'source': 'if dataset_id_to_erase:\n    erase.erase_dataset(datamart_api_url, dataset_id_to_erase)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.867820',
#      'end_time': '2020-11-25T05:20:11.883874',
#      'duration': 0.016054,
#      'status': 'completed'}},
#    'source': '### Build the annotated sheet, and add it to Datamart'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.901976',
#      'end_time': '2020-11-25T05:20:11.930364',
#      'duration': 0.028388,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:11.926116Z',
#      'iopub.execute_input': '2020-11-25T05:20:11.926840Z',
#      'shell.execute_reply': '2020-11-25T05:20:11.929457Z',
#      'iopub.status.idle': '2020-11-25T05:20:11.930182Z'}},
#    'outputs': [],
#    'source': 'nfiles, nsheets = 0, 0\nif template_path and dataset_path:\n    if dataset_id is None:\n        dataset_id = utility.read_tsv(template_path).iat[0,1]\n\n    nfiles, nsheets = upload.submit_sheet_bulk(datamart_api_url, template_path, \n                                               dataset_path, flag_combine_files, put_data)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.947464',
#      'end_time': '2020-11-25T05:20:11.963677',
#      'duration': 0.016213,
#      'status': 'completed'}},
#    'source': '### If needed, save the template'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:11.979963',
#      'end_time': '2020-11-25T05:20:12.007910',
#      'duration': 0.027947,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:12.002908Z',
#      'iopub.execute_input': '2020-11-25T05:20:12.003691Z',
#      'iopub.status.idle': '2020-11-25T05:20:12.006795Z',
#      'shell.execute_reply': '2020-11-25T05:20:12.007657Z'}},
#    'outputs': [],
#    'source': 'if not save_template_path is None:\n    template.save_annotation_template(utility.read_tsv(template_path), save_template_path)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:12.028456',
#      'end_time': '2020-11-25T05:20:12.045302',
#      'duration': 0.016846,
#      'status': 'completed'}},
#    'source': '### Get the annotated sheet, and add it to Datamart\n\nReturned files will be saved at save_tsv or save_files'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:12.061736',
#      'end_time': '2020-11-25T05:20:52.217820',
#      'duration': 40.156084,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:12.085844Z',
#      'iopub.execute_input': '2020-11-25T05:20:12.086571Z',
#      'iopub.status.idle': '2020-11-25T05:20:52.216595Z',
#      'shell.execute_reply': '2020-11-25T05:20:52.217458Z'}},
#    'outputs': [],
#    'source': 'if annotated_path:\n    if upload.submit_annotated_sheet(datamart_api_url, annotated_path, yamlfile_path, put_data=put_data,\n                                        verbose=Verbose, save_tsv=save_tsv_path, save_files=save_t2wml_path):\n        nsheets += 1\n        nfiles += 1'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:52.792301',
#      'end_time': '2020-11-25T05:20:52.813462',
#      'duration': 0.021161,
#      'status': 'completed'}},
#    'source': '### Get tsv file, and add it to Datamart'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:52.831312',
#      'end_time': '2020-11-25T05:20:52.859012',
#      'duration': 0.0277,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:52.854589Z',
#      'iopub.execute_input': '2020-11-25T05:20:52.855310Z',
#      'iopub.status.idle': '2020-11-25T05:20:52.858210Z',
#      'shell.execute_reply': '2020-11-25T05:20:52.858797Z'}},
#    'outputs': [],
#    'source': 'if tsv_path:\n    if upload.submit_tsv(datamart_api_url, tsv_path, put_data=put_data):\n        nfiles += 1'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:52.879079',
#      'end_time': '2020-11-25T05:20:52.896647',
#      'duration': 0.017568,
#      'status': 'completed'}},
#    'source': '### Generate statistics for bug checking'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:52.916387',
#      'end_time': '2020-11-25T05:20:52.944813',
#      'duration': 0.028426,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:52.939245Z',
#      'iopub.execute_input': '2020-11-25T05:20:52.939986Z',
#      'shell.execute_reply': '2020-11-25T05:20:52.943815Z',
#      'iopub.status.idle': '2020-11-25T05:20:52.944567Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '1 files processed.\n1 sheets uploaded.\n'}],
#    'source': "print(f'{nfiles} files processed.')\nprint(f'{nsheets} sheets uploaded.')"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:52.965400',
#      'end_time': '2020-11-25T05:20:52.983542',
#      'duration': 0.018142,
#      'status': 'completed'}},
#    'source': '### Visualization to check errors'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-11-25T05:20:53.001747',
#      'end_time': '2020-11-25T05:20:53.030139',
#      'duration': 0.028392,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-11-25T05:20:53.025495Z',
#      'iopub.execute_input': '2020-11-25T05:20:53.026215Z',
#      'iopub.status.idle': '2020-11-25T05:20:53.029239Z',
#      'shell.execute_reply': '2020-11-25T05:20:53.029890Z'}},
#    'outputs': [],
#    'source': 'if nsheets > 0 and DEBUG:\n    test.visualize(datamart_api_url, dataset_id)'}],
#  'metadata': {'celltoolbar': 'Tags',
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.8',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'datamart_api_url': 'http://localhost:12543',
#     'annotated_path': '/lfs1/ktyao/Shared/kgtk-private-data/world-modelers/MITRE Annotated Datasets for Dec 2020/ACLED/ACLED_1997-01-01-2020-11-12-Ethiopia_ANNOTATED_MODIFIED-partial.xlsx',
#     'save_tsv_path': '/lfs1/ktyao/Shared/kgtk-private-data/world-modelers/kgtk/ACLED.tar.gz'},
#    'environment_variables': {},
#    'version': '2.2.2',
#    'input_path': '/home/ktyao/dev/dsbox/datamart-api/data-refresh/DataLoader.ipynb',
#    'output_path': '/lfs1/ktyao/Shared/kgtk-private-data/world-modelers/executed_notebook/acled.ipynb',
#    'start_time': '2020-11-25T05:20:09.566708',
#    'end_time': '2020-11-25T05:20:53.367431',
#    'duration': 43.800723,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}
